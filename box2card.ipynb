# %%
# !pip install mwparserfromhell
# !pip install wptools
import re
import json
import wptools
from mwparserfromhell import parse
from mwparserfromhell.wikicode import Wikicode
from mwparserfromhell.nodes.argument import Argument
from mwparserfromhell.nodes.comment import Comment
from mwparserfromhell.nodes.external_link import ExternalLink
from mwparserfromhell.nodes.heading import Heading
from mwparserfromhell.nodes.html_entity import HTMLEntity
from mwparserfromhell.nodes.tag import Tag
from mwparserfromhell.nodes.template import Template
from mwparserfromhell.nodes.text import Text
from mwparserfromhell.nodes.wikilink import Wikilink
from mwparserfromhell.nodes.extras.parameter import Parameter
# Out:
# Collecting mwparserfromhell
#   Downloading mwparserfromhell-0.6.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (176 kB)
#      |████████████████████████████████| 176 kB 23.3 MB/s
# Installing collected packages: mwparserfromhell
# Successfully installed mwparserfromhell-0.6.4
# Collecting wptools
#   Downloading wptools-0.4.17-py2.py3-none-any.whl (38 kB)
# Collecting html2text
#   Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Collecting pycurl
#   Downloading pycurl-7.45.1.tar.gz (233 kB)
#      |████████████████████████████████| 233 kB 46.7 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from wptools) (2021.10.8)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from wptools) (4.2.6)
# Building wheels for collected packages: pycurl
#   Building wheel for pycurl (setup.py) ... done
#   Created wheel for pycurl: filename=pycurl-7.45.1-cp37-cp37m-linux_x86_64.whl size=300949 sha256=c7f0c77691a2f8133335b1898a8a4548c77835183e0fe4a5c206542e7fa897e3
#   Stored in directory: /root/.cache/pip/wheels/b4/fe/1f/e6cae4153dbc082271bd5763ad36ae255639e4641054db10bc
# Successfully built pycurl
# Installing collected packages: pycurl, html2text, wptools
# Successfully installed html2text-2020.1.16 pycurl-7.45.1 wptools-0.4.17

# %%
def render_template(node, name, params):
  name = name.lower().strip().replace("\n", "")
  try:
    if name == "nasdaq":
      return params["1"]

    # if name == "nobold":
    #   return params["1"]
    if name == "nowrap":
      return params["1"]

    if name == "country abbreviation":
      return params["1"]

    if name == "replace":
      return params["1"]

    if name == "formatnum":
      return params["0"]

    if name == "lang":
      return params["2"]

    if name == "small":
      return params["1"]
    
    if name == "flatlist":
      return " + ' ' + ".join([params[param] for param in params])
    
    if name == "convert" or name == "cvt":
      return f"{params['1']} + ' ' + {params['2']}"
    
    if name == "increase":
      return render("▲")
    
    if name == "decrease":
      return render("▼")
    
    if name == "us$":
      return render("US$") + " + " + params["1"]
    
    if name == "plainlist":
      return " + '\n' + ".join([params[param] for param in params])
    
    if name == "break":
      return render("\n")
    
    if name == "lc":
      return "toLower(" + params["0"] + ")"
    
    if name == "nbsp":
      return render(" ")
    
    if name == "url":
      url = params['1']
      if "http" not in url:
        return f"'[' + {params['1']} + '](http://' + {params['1']} + ')'"
      else:
        return f"'[' + {params['1']} + '](' + {params['1']} + ')'" 
    
    if name == "coord":
      lat = float(params["1"][1:-1])
      lon = float(params["2"][1:-1])
      a = "N" if lat >= 0 else "S"
      b = "E" if lat >= 0 else "W"
      return f"'{lat}' + '°{a} ' + '{lon}' + '°{b}'"
    
    if name == "both":
      return f"if({params['0']} != '' && {params['1']} != '', '1', '')"
    
    if name == "#if":
      return f"if(trim({params['0']}) != '', {params['1']}, {params['2'] if '2' in params else render('')})"
    
    if name == "#replace":
      return f"replace({params['0']}, {params['1']}, {params['2']})"
    
    if name == "#ifexist":
      return params["1"]
    
    if name == "#ifeq":
      return "if(" + params["0"] + " == " + params["1"] + ", " + params["2"] + ", " + (params["3"] if "3" in params else render('')) + ")"
    
    if name == "if empty":
      return params["1"]
    
    if name == "pluralize from text":
      return render("")
    
    if name == "delink":
      return params["1"]
    
    if name == "abbr":
      return params["1"]
    
    if name == "longitem":
      return params["1"]
    
    if name == "infobox":
      return render(params)
    
    if name == "pagenamebase":
      return render("PAGENAMEBASE")
    
    if name == "br separated entries" or name == "unbulleted list" or name == "hlist":
      return " + '\n' + ".join([params[param] for param in params])
    
    if name == "comma separated entries":
      return " + ', ' + ".join([params[param] for param in params])
    
    if name == "#switch":
      if "#default" in params:
        return params["#default"]
      for param in params:
        if param != "0":
          return params[param]
    
    if name == "#invoke":
      module = params["0"].lower().replace("'", "")
      if module == "infoboximage":
        return params["image"]
      if module == "hms":
        return params["duration"]
      if module == "string":
        if params["1"] == "'replace'":
          return params["2"]
      if module == "coordinates":
          return params["2"]

  except Exception as error:
    print(f"Error ocurred in render_template({name}): {error}")

  print(f"Error: Template named '{name}' is not implemented: {params}")

  # # Fallback
  # if len(params) == 0:
  #   return render(None)

  # if len(params) == 1:
  #   for param in params:
  #     return params[param]

  return render(None)

def render(node, preserveWhitespace=True):
  if node is None:
    return render('')

  if type(node) is str:
    if preserveWhitespace:
      return "'" + node + "'"
    else:
      return "'" + node.strip() + "'"

  if type(node) is Text:
    return render(str(node))

  if type(node) is Parameter:
    return render(node.value)

  if type(node) is Template:
    param0 = []
    name = node.name.strip()
    if ":" in name:
      name = node.name.split(":")[0]
      param0 = [Parameter("0", node.name[len(name)+1:].strip())]
    params = param0 + node.params
    params = { param.name.strip(): render(param.value) for param in params }
    return render_template(node, name, params)

  if type(node) is Argument:
    name = str(node.name).replace(" ", "_").replace("-", "_")
    if name[0] in "0123456789":
      print("Illegal variable name:", name)
      name = "n" + name
    default = render(node.default)
    return f"if({name} != null, {name}, {default})"

  if type(node) is Wikicode:
    rendered_nodes = [render(node) for node in node.nodes]
    filtered_nodes = [node for node in rendered_nodes if node]
    if len(filtered_nodes) == 0:
      return render('')
    return " + ".join(filtered_nodes)

  if type(node) is Wikilink:
    return render(node.text or node.title)

  if type(node) is ExternalLink:
    return render(f"[{node.title or node.url}]({node.url})")
    
  if type(node) is Tag:
    if node.tag == "includeonly":
      return render(None)
      
    if node.tag == "br":
      return render("\n")
    if node.tag == "b":
      return render(f"**{node.contents}**")
    if node.tag == "i":
      return render(f"*{node.contents}*")
    if node.tag == "li":
      return render(f"\n * {node.contents}")
    return render(node.contents)

  if type(node) is Comment:
    return render(None)

  if type(node) is HTMLEntity:
    return render(str(node))

  print(f"Rendering for node of type {type(node)} is not implemented.")
  return str(type(node)) + " " + str(node)

def wrap_expression(node):
  return "${" + str(node) + "}"
  
def insert_component(prop, infobox, body): 
  if "above" == prop:
    title = wrap_expression(infobox[prop])
    if not title:
      title = wrap_expression("name")

    return body.append({
          "type": "Container",
          "style": "emphasis",
          "$data": title,
          "$when": "${length(trim($data)) > 0}",
          "items": [{
            "type": "TextBlock",
            "text": "${$data}",
            "style": "heading",
            "wrap": "true",
            "horizontalAlignment": "Center"
          }]
        })
      
  title = None
  if "title" == prop:
    title = wrap_expression(infobox[prop])
    if not title:
      title = wrap_expression("name")

    body.append({
          "type": "Container",
          "style": "emphasis",
          "$data": title,
          "$when": "${length(trim($data)) > 0}",
          "items": [{
            "type": "TextBlock",
            "text": "${$data}",
            "style": "heading",
            "wrap": "true",
            "horizontalAlignment": "Center"
          }]
        })
      
  subheader = None
  if re.match("^subheader[\d]*$", prop):
    subheader = wrap_expression(infobox[prop])

    body.append({
        "type": "Container",
        "$data": subheader,
        "$when": "${length(trim($data)) > 0}",
        "items": [{
          "type": "TextBlock",
          "text": "${$data}",
          "wrap": "true",
          "horizontalAlignment": "Center"
        }]
      })

  if re.match("^image[\d]*$", prop):
    url = wrap_expression(infobox[prop])
    if url:
      body.append({
          "type": "Image",
          "horizontalAlignment": "Center",
          "$data": url,
          "url": "${$data}",
          "$when": "${length(trim($data)) > 0}",
      })    
  
  if re.match("^caption[\d]*$", prop):
      text = wrap_expression(infobox[prop])
      if text:
        body.append({
            "type": "TextBlock",
            "$data": text,
            "text": "${$data}",
            "horizontalAlignment": "Center",
            "$when": "${length(trim($data)) > 0}",        
            "wrap": "true",
        })

  if re.match("^header[\d]*$", prop):
      text = wrap_expression(infobox[prop])
      body.append(
          {
              "type": "Container",
              "style": "emphasis",
              "wrap": "true",
              "$data": text, 
              "$when": "${length(trim($data)) > 0}",        
              "items": [
                {
                  "type": "TextBlock",
                  "text": "${$data}", 
                  "weight": "Bolder",
                  "horizontalAlignment": "Center",
                }
              ]
          }
      )

  label_prop = prop.replace("data", "label")
  data_prop = prop.replace("label", "data")
  if "data" in data_prop and "label" in label_prop and label_prop in infobox and data_prop in infobox:
    # Wait for label only
    if label_prop == prop:
        try:
          facts = body[len(body) - 1]["facts"]
        except:
          facts = []
          body.append(
              {
                  "type": "FactSet",
                  "facts": facts
              }
          )

        l = infobox[label_prop]
        d = infobox[data_prop]
        facts.append({ 
            "title": "${$data.title}",
            "$data": "${{'data': " + d + ", 'title': " + l + "}}",
            "value": "${$data.data}",
            "$when": "${length(trim($data.data)) > 0}"
        })
  elif "data" in prop or "label" in prop: 
    if prop == label_prop:      
      print(f"ERROR: label {prop} does not have an associated data.")
    elif prop == data_prop:
      # Add standalone data (no label)
      data = wrap_expression(infobox[prop])
      body.append(
          {
            "$data": data, 
            "$when": "${length(trim($data)) > 0}",        
            "type": "TextBlock",
            "text": "${$data}", 
            "horizontalAlignment": "Center",
          }
      )

def infobox_to_card(template, wikipedia_url=None):
  code = parse(template)
  templates = code.filter_templates(recursive=True)
  infobox_node = [template for template in templates if template.name.lower().strip() == "infobox"][0]
  print(infobox_node)
  print(infobox_node.params)
  infobox = { param.name.strip(): render(param) for param in infobox_node.params }
  body = []
  print(infobox)
  for prop in infobox:
    insert_component(prop, infobox, body)

  payload = {
      "type": "AdaptiveCard",
      "$schema": "http://adaptivecards.io/schemas/adaptive-card.json",
      "version": "1.5",
      "body": body,
      "actions": [
        {
          "type": "Action.OpenUrl",
          "title": "Wikipedia",
          "url": wikipedia_url
        }
      ]
  }

  payload_json = json.dumps(payload)
  return payload_json

def get_data_and_template(title):
  wikipedia_url = "https://en.wikipedia.org/wiki/" + title
  so = wptools.page(title).get_parse()
  box = so.data["infobox"]
  def prepare(prop):
    prop = prop.replace("'", "\\'").replace("\n", "\\n")
    a = parse(prop)
    b = render(a, preserveWhitespace=True).replace("\n", " ")
    c = eval(b)
    return c

  parsed = { prop.replace(" ", "_").replace("-", "_"): prepare(box[prop]) for prop in box }
  if "image" in so.data:
    for k, v in parsed.items():
      for i in so.data["image"]:
        if i["orig"] == v:
          parsed[k] = i["url"]
  data_json = json.dumps(parsed)

  so.data["wikitext"]
  text = so.data["wikitext"]
  i = text.lower().index("infobox")
  j = text[i:].index("|")
  infobox_template_title = text[i:i+j].strip()
  print(f"Fetching infobox template {infobox_template_title}")
  so = wptools.page('Template:' + infobox_template_title).get_parse()
  infobox_template = so.data["wikitext"]
  print(infobox_template)
  template_json = infobox_to_card(infobox_template, wikipedia_url)

  return data_json, template_json

# %%
title = "Milky Way" #@param {type: "string"}
title = title.replace(" ", "_")

data, template = get_data_and_template(title)

# Saving template and data to files
with open(f"{title}.template.json", "w") as f:
  f.write(template)

with open(f"{title}.data.json", "w") as f:
  f.write(data)

print("==========================")

print("Adaptive Cards template:")
print(template)

print("Adaptive Cards data:")
print(data)

print("==========================")
# Out:
# en.wikipedia.org (parse) Milky_Way
# Milky Way (en) data
# {
#   image: <list(0)>
#   infobox: <dict(6)> name, epoch, constellation name, image, type, size
#   iwlinks: <list(3)> https://commons.wikimedia.org/wiki/Category:M...
#   pageid: 2589714
#   parsetree: <str(243067)> <root><template><title>Short descriptio...
#   requests: <list(1)> parse
#   title: Milky Way
#   wikibase: Q321
#   wikidata_url: https://www.wikidata.org/wiki/Q321
#   wikitext: <str(191534)> {{Short description|Barred spiral galaxy...
# }
# en.wikipedia.org (parse) Template:Infobox galaxy
# Template:Infobox galaxy (en) data
# {
#   image: <list(0)>
#   infobox: <dict(41)> image, abovestyle, headerstyle, belowstyle, ...
#   pageid: 970028
#   parsetree: <str(15964)> <root><template><title>Infobox</title><p...
#   requests: <list(1)> parse
#   title: Template:Infobox galaxy
#   wikibase: Q5882327
#   wikidata_url: https://www.wikidata.org/wiki/Q5882327
#   wikitext: <str(5557)> {{Infobox| above    = {{{name<includeonly>...
# }
# Fetching infobox template Infobox galaxy
# {{Infobox
# | above    = {{{name<includeonly>|{{PAGENAME}}</includeonly>}}}
# | image    = {{#invoke:InfoboxImage|InfoboxImage|image={{{image<includeonly>|</includeonly>}}}|size={{{image_size|}}}|sizedefault=frameless|upright={{{upright|}}}|alt={{{alt|}}}}}
# | caption = {{{caption<includeonly>|</includeonly>}}}
# | abovestyle  = background: #ddd;
# | headerstyle = background: #ddd;
# | belowstyle  = background: #ddd;
# | labelstyle  = background: inherit;
#
# |header1 = Observation data {{#if:{{{epoch<includeonly>|</includeonly>}}}|({{{epoch}}} [[Epoch (astronomy)|epoch]]) }}
# | label2 = Pronunciation
# |  data2 = {{{pronounce<includeonly>|</includeonly>}}}
#
# | label3 = [[Constellation]]
# |  data3 = {{{constellation name<includeonly>|</includeonly>}}}
# | label4 = [[Right ascension]]
# |  data4 = {{{ra<includeonly>|</includeonly>}}}
# | label5 = [[Declination]]
# |  data5 = {{{dec<includeonly>|</includeonly>}}}
#
# | label6 = [[Redshift]]
# |  data6 = {{{z<includeonly>|</includeonly>}}}
# | label7 = [[Radial velocity|Helio radial velocity]]
# |  data7 = {{{h_radial_v<includeonly>|</includeonly>}}}
# | label8 = Galactocentric velocity
# |  data8 = {{{gal_v<includeonly>|</includeonly>}}}
# | label9 = [[Comoving distance|Distance (comoving)]]
# |  data9 = {{{dist_pc<includeonly>|</includeonly>}}}
# | label10 = [[Cosmic distance ladder|Distance]]
# |  data10 = {{{dist_ly<includeonly>|</includeonly>}}}
# | label11 = [[Galaxy group|Group]] or [[Galaxy cluster|cluster]]
# |  data11 = {{{group_cluster<includeonly>|</includeonly>}}}
# | label12 = [[Apparent magnitude]]&nbsp;<small title="in visual light">(V)</small>
# |  data12 = {{{appmag_v<includeonly>|</includeonly>}}}
# | label13 = [[Apparent magnitude]]&nbsp;<small title="in B band">(B)</small>
# |  data13 = {{{appmag_b<includeonly>|</includeonly>}}}
# | label14 = [[Absolute magnitude]]&nbsp;<small title="in visual light">(V)</small>
# |  data14 = {{{absmag_v<includeonly>|</includeonly>}}}
# | label15 = [[Absolute magnitude]]&nbsp;<small title="in visual light">(B)</small>
# |  data15 = {{{absmag_b<includeonly>|</includeonly>}}}
# | label16 = [[Surface brightness]]&nbsp;<small title="in visual light">(specify)</small>
# |  data16 = {{{sbrightness_specify<includeonly>|</includeonly>}}}
#
# |header20 = {{#if:{{{type<includeonly>|</includeonly>}}}{{{mass<includeonly>|</includeonly>}}}{{{mass_light_ratio<includeonly>|</includeonly>}}}{{{size<includeonly>|</includeonly>}}}{{{stars<includeonly>|</includeonly>}}}{{{size_v<includeonly>|</includeonly>}}}{{{half_light_radius_pc<includeonly>|</includeonly>}}}{{{half_light_radius_arcminsec<includeonly>|</includeonly>}}}{{{h1_scale_length_pc<includeonly>|</includeonly>}}}{{{h1_scale_length_arcminsec<includeonly>|</includeonly>}}}{{{xray_radius_pc<includeonly>|</includeonly>}}}{{{xray_radius_arcminsec<includeonly>|</includeonly>}}}|Characteristics}}
# | label21 = [[Galaxy morphological classification|Type]]
# |  data21 = {{{type<includeonly>|</includeonly>}}}
# | label22 = [[Mass]]
# |  data22 = {{#if:{{{mass<includeonly>|</includeonly>}}}|{{{mass}}}&nbsp;{{solar mass|link=yes}}}}
# | label23 = [[Mass-to-light ratio|Mass/Light ratio]]
# |  data23 = {{#if:{{{mass_light_ratio<includeonly>|</includeonly>}}}|{{{mass_light_ratio}}}&nbsp;{{solar mass|link=yes}}/{{solar luminosity|link=yes}}}}
# | label24 = Number of stars
# |  data24 = {{{stars<includeonly>|</includeonly>}}}
# | label25 = Size
# |  data25 = {{#if:{{{size<includeonly>|</includeonly>}}}|{{{size}}}}}
# | label26 = [[Angular diameter|Apparent size]]&nbsp;<small title="in visual light">(V)</small>
# |  data26 = {{{size_v<includeonly>|</includeonly>}}}
# | label27 = [[Half-light radius]]&nbsp;<small title="in visual light">(physical)</small>
# |  data27 = {{{half_light_radius_pc<includeonly>|</includeonly>}}}
# | label28 = [[Half-light radius]]&nbsp;<small title="in visual light">(apparent)</small>
# |  data28 = {{{half_light_radius_arcminsec<includeonly>|</includeonly>}}}
# | label29 = [[H I region|H I scale length]]&nbsp;<small title="in visual light">(physical)</small>
# |  data29 = {{{h1_scale_length_pc<includeonly>|</includeonly>}}}
# | label30 = [[H I region|H I scale length]]&nbsp;<small title="in visual light">(apparent)</small>
# |  data30 = {{{h1_scale_length_arcminsec<includeonly>|</includeonly>}}}
# | label31 = [[X-ray astronomy|X-ray radius]]&nbsp;<small title="in visual light">(physical)</small>
# |  data31 = {{{xray_radius_pc<includeonly>|</includeonly>}}}
# | label32 = [[X-ray astronomy|X-ray radius]]&nbsp;<small title="in visual light">(apparent)</small>
# |  data32 = {{{xray_radius_arcminsec<includeonly>|</includeonly>}}}
#
# | label35 = Notable features
# |  data35 = {{{notes<includeonly>|</includeonly>}}}
# |header40 = {{#if:{{{names<includeonly>|</includeonly>}}} | Other designations }}
# |  data41 = {{{names<includeonly>|</includeonly>}}}
#
# |  data42 = {{#if:{{{references<includeonly>|</includeonly>}}}|<div style="font-size:95%">'''References''': {{{references}}}</div>}}
#
# | belowclass = noprint
# }}{{#invoke:Check for unknown parameters|check|unknown={{main other|}}|preview=Page using [[Template:Infobox galaxy]] with unknown parameter "_VALUE_"| ignoreblank=y | name | image | image_size | upright | caption | alt | epoch | pronounce | constellation name | ra | dec | z | h_radial_v | gal_v | dist_pc | dist_ly | group_cluster | type | mass | mass_light_ratio | size | stars | appmag_v | appmag_b | absmag_v | size_v | half_light_radius_pc | half_light_radius_arcminsec | h1_scale_length_pc | h1_scale_length_arcminsec | xray_radius_pc | xray_radius_arcminsec | notes | names | references }}<noinclude>
# {{Documentation}}<!--Please add this template's categories to the /doc subpage, not here - thanks!-->
# </noinclude>
# {{Infobox
# | above    = {{{name<includeonly>|{{PAGENAME}}</includeonly>}}}
# | image    = {{#invoke:InfoboxImage|InfoboxImage|image={{{image<includeonly>|</includeonly>}}}|size={{{image_size|}}}|sizedefault=frameless|upright={{{upright|}}}|alt={{{alt|}}}}}
# | caption = {{{caption<includeonly>|</includeonly>}}}
# | abovestyle  = background: #ddd;
# | headerstyle = background: #ddd;
# | belowstyle  = background: #ddd;
# | labelstyle  = background: inherit;
#
# |header1 = Observation data {{#if:{{{epoch<includeonly>|</includeonly>}}}|({{{epoch}}} [[Epoch (astronomy)|epoch]]) }}
# | label2 = Pronunciation
# |  data2 = {{{pronounce<includeonly>|</includeonly>}}}
#
# | label3 = [[Constellation]]
# |  data3 = {{{constellation name<includeonly>|</includeonly>}}}
# | label4 = [[Right ascension]]
# |  data4 = {{{ra<includeonly>|</includeonly>}}}
# | label5 = [[Declination]]
# |  data5 = {{{dec<includeonly>|</includeonly>}}}
#
# | label6 = [[Redshift]]
# |  data6 = {{{z<includeonly>|</includeonly>}}}
# | label7 = [[Radial velocity|Helio radial velocity]]
# |  data7 = {{{h_radial_v<includeonly>|</includeonly>}}}
# | label8 = Galactocentric velocity
# |  data8 = {{{gal_v<includeonly>|</includeonly>}}}
# | label9 = [[Comoving distance|Distance (comoving)]]
# |  data9 = {{{dist_pc<includeonly>|</includeonly>}}}
# | label10 = [[Cosmic distance ladder|Distance]]
# |  data10 = {{{dist_ly<includeonly>|</includeonly>}}}
# | label11 = [[Galaxy group|Group]] or [[Galaxy cluster|cluster]]
# |  data11 = {{{group_cluster<includeonly>|</includeonly>}}}
# | label12 = [[Apparent magnitude]]&nbsp;<small title="in visual light">(V)</small>
# |  data12 = {{{appmag_v<includeonly>|</includeonly>}}}
# | label13 = [[Apparent magnitude]]&nbsp;<small title="in B band">(B)</small>
# |  data13 = {{{appmag_b<includeonly>|</includeonly>}}}
# | label14 = [[Absolute magnitude]]&nbsp;<small title="in visual light">(V)</small>
# |  data14 = {{{absmag_v<includeonly>|</includeonly>}}}
# | label15 = [[Absolute magnitude]]&nbsp;<small title="in visual light">(B)</small>
# |  data15 = {{{absmag_b<includeonly>|</includeonly>}}}
# | label16 = [[Surface brightness]]&nbsp;<small title="in visual light">(specify)</small>
# |  data16 = {{{sbrightness_specify<includeonly>|</includeonly>}}}
#
# |header20 = {{#if:{{{type<includeonly>|</includeonly>}}}{{{mass<includeonly>|</includeonly>}}}{{{mass_light_ratio<includeonly>|</includeonly>}}}{{{size<includeonly>|</includeonly>}}}{{{stars<includeonly>|</includeonly>}}}{{{size_v<includeonly>|</includeonly>}}}{{{half_light_radius_pc<includeonly>|</includeonly>}}}{{{half_light_radius_arcminsec<includeonly>|</includeonly>}}}{{{h1_scale_length_pc<includeonly>|</includeonly>}}}{{{h1_scale_length_arcminsec<includeonly>|</includeonly>}}}{{{xray_radius_pc<includeonly>|</includeonly>}}}{{{xray_radius_arcminsec<includeonly>|</includeonly>}}}|Characteristics}}
# | label21 = [[Galaxy morphological classification|Type]]
# |  data21 = {{{type<includeonly>|</includeonly>}}}
# | label22 = [[Mass]]
# |  data22 = {{#if:{{{mass<includeonly>|</includeonly>}}}|{{{mass}}}&nbsp;{{solar mass|link=yes}}}}
# | label23 = [[Mass-to-light ratio|Mass/Light ratio]]
# |  data23 = {{#if:{{{mass_light_ratio<includeonly>|</includeonly>}}}|{{{mass_light_ratio}}}&nbsp;{{solar mass|link=yes}}/{{solar luminosity|link=yes}}}}
# | label24 = Number of stars
# |  data24 = {{{stars<includeonly>|</includeonly>}}}
# | label25 = Size
# |  data25 = {{#if:{{{size<includeonly>|</includeonly>}}}|{{{size}}}}}
# | label26 = [[Angular diameter|Apparent size]]&nbsp;<small title="in visual light">(V)</small>
# |  data26 = {{{size_v<includeonly>|</includeonly>}}}
# | label27 = [[Half-light radius]]&nbsp;<small title="in visual light">(physical)</small>
# |  data27 = {{{half_light_radius_pc<includeonly>|</includeonly>}}}
# | label28 = [[Half-light radius]]&nbsp;<small title="in visual light">(apparent)</small>
# |  data28 = {{{half_light_radius_arcminsec<includeonly>|</includeonly>}}}
# | label29 = [[H I region|H I scale length]]&nbsp;<small title="in visual light">(physical)</small>
# |  data29 = {{{h1_scale_length_pc<includeonly>|</includeonly>}}}
# | label30 = [[H I region|H I scale length]]&nbsp;<small title="in visual light">(apparent)</small>
# |  data30 = {{{h1_scale_length_arcminsec<includeonly>|</includeonly>}}}
# | label31 = [[X-ray astronomy|X-ray radius]]&nbsp;<small title="in visual light">(physical)</small>
# |  data31 = {{{xray_radius_pc<includeonly>|</includeonly>}}}
# | label32 = [[X-ray astronomy|X-ray radius]]&nbsp;<small title="in visual light">(apparent)</small>
# |  data32 = {{{xray_radius_arcminsec<includeonly>|</includeonly>}}}
#
# | label35 = Notable features
# |  data35 = {{{notes<includeonly>|</includeonly>}}}
# |header40 = {{#if:{{{names<includeonly>|</includeonly>}}} | Other designations }}
# |  data41 = {{{names<includeonly>|</includeonly>}}}
#
# |  data42 = {{#if:{{{references<includeonly>|</includeonly>}}}|<div style="font-size:95%">'''References''': {{{references}}}</div>}}
#
# | belowclass = noprint
# }}
# [' above    = {{{name<includeonly>|{{PAGENAME}}</includeonly>}}}\n', ' image    = {{#invoke:InfoboxImage|InfoboxImage|image={{{image<includeonly>|</includeonly>}}}|size={{{image_size|}}}|sizedefault=frameless|upright={{{upright|}}}|alt={{{alt|}}}}}\n', ' caption = {{{caption<includeonly>|</includeonly>}}}\n', ' abovestyle  = background: #ddd;\n', ' headerstyle = background: #ddd;\n', ' belowstyle  = background: #ddd;\n', ' labelstyle  = background: inherit;\n\n', 'header1 = Observation data {{#if:{{{epoch<includeonly>|</includeonly>}}}|({{{epoch}}} [[Epoch (astronomy)|epoch]]) }}\n', ' label2 = Pronunciation\n', '  data2 = {{{pronounce<includeonly>|</includeonly>}}}\n\n', ' label3 = [[Constellation]]\n', '  data3 = {{{constellation name<includeonly>|</includeonly>}}}\n', ' label4 = [[Right ascension]]\n', '  data4 = {{{ra<includeonly>|</includeonly>}}}\n', ' label5 = [[Declination]]\n', '  data5 = {{{dec<includeonly>|</includeonly>}}}\n\n', ' label6 = [[Redshift]]\n', '  data6 = {{{z<includeonly>|</includeonly>}}}\n', ' label7 = [[Radial velocity|Helio radial velocity]]\n', '  data7 = {{{h_radial_v<includeonly>|</includeonly>}}}\n', ' label8 = Galactocentric velocity\n', '  data8 = {{{gal_v<includeonly>|</includeonly>}}}\n', ' label9 = [[Comoving distance|Distance (comoving)]]\n', '  data9 = {{{dist_pc<includeonly>|</includeonly>}}}\n', ' label10 = [[Cosmic distance ladder|Distance]]\n', '  data10 = {{{dist_ly<includeonly>|</includeonly>}}}\n', ' label11 = [[Galaxy group|Group]] or [[Galaxy cluster|cluster]]\n', '  data11 = {{{group_cluster<includeonly>|</includeonly>}}}\n', ' label12 = [[Apparent magnitude]]&nbsp;<small title="in visual light">(V)</small>\n', '  data12 = {{{appmag_v<includeonly>|</includeonly>}}}\n', ' label13 = [[Apparent magnitude]]&nbsp;<small title="in B band">(B)</small>\n', '  data13 = {{{appmag_b<includeonly>|</includeonly>}}}\n', ' label14 = [[Absolute magnitude]]&nbsp;<small title="in visual light">(V)</small>\n', '  data14 = {{{absmag_v<includeonly>|</includeonly>}}}\n', ' label15 = [[Absolute magnitude]]&nbsp;<small title="in visual light">(B)</small>\n', '  data15 = {{{absmag_b<includeonly>|</includeonly>}}}\n', ' label16 = [[Surface brightness]]&nbsp;<small title="in visual light">(specify)</small>\n', '  data16 = {{{sbrightness_specify<includeonly>|</includeonly>}}}\n\n', 'header20 = {{#if:{{{type<includeonly>|</includeonly>}}}{{{mass<includeonly>|</includeonly>}}}{{{mass_light_ratio<includeonly>|</includeonly>}}}{{{size<includeonly>|</includeonly>}}}{{{stars<includeonly>|</includeonly>}}}{{{size_v<includeonly>|</includeonly>}}}{{{half_light_radius_pc<includeonly>|</includeonly>}}}{{{half_light_radius_arcminsec<includeonly>|</includeonly>}}}{{{h1_scale_length_pc<includeonly>|</includeonly>}}}{{{h1_scale_length_arcminsec<includeonly>|</includeonly>}}}{{{xray_radius_pc<includeonly>|</includeonly>}}}{{{xray_radius_arcminsec<includeonly>|</includeonly>}}}|Characteristics}}\n', ' label21 = [[Galaxy morphological classification|Type]]\n', '  data21 = {{{type<includeonly>|</includeonly>}}}\n', ' label22 = [[Mass]]\n', '  data22 = {{#if:{{{mass<includeonly>|</includeonly>}}}|{{{mass}}}&nbsp;{{solar mass|link=yes}}}}\n', ' label23 = [[Mass-to-light ratio|Mass/Light ratio]]\n', '  data23 = {{#if:{{{mass_light_ratio<includeonly>|</includeonly>}}}|{{{mass_light_ratio}}}&nbsp;{{solar mass|link=yes}}/{{solar luminosity|link=yes}}}}\n', ' label24 = Number of stars\n', '  data24 = {{{stars<includeonly>|</includeonly>}}}\n', ' label25 = Size\n', '  data25 = {{#if:{{{size<includeonly>|</includeonly>}}}|{{{size}}}}}\n', ' label26 = [[Angular diameter|Apparent size]]&nbsp;<small title="in visual light">(V)</small>\n', '  data26 = {{{size_v<includeonly>|</includeonly>}}}\n', ' label27 = [[Half-light radius]]&nbsp;<small title="in visual light">(physical)</small>\n', '  data27 = {{{half_light_radius_pc<includeonly>|</includeonly>}}}\n', ' label28 = [[Half-light radius]]&nbsp;<small title="in visual light">(apparent)< ...
# Error: Template named 'solar mass' is not implemented: {'link': "'yes'"}
# Error: Template named 'solar mass' is not implemented: {'link': "'yes'"}
# Error: Template named 'solar luminosity' is not implemented: {'link': "'yes'"}
# {'above': "' ' + if(name<includeonly>|{{PAGENAME}}</includeonly> != null, name<includeonly>|{{PAGENAME}}</includeonly>, '') + '\n'", 'image': "' ' + if(image<includeonly>|</includeonly> != null, image<includeonly>|</includeonly>, '') + '\n'", 'caption': "' ' + if(caption<includeonly>|</includeonly> != null, caption<includeonly>|</includeonly>, '') + '\n'", 'abovestyle': "' background: #ddd;\n'", 'headerstyle': "' background: #ddd;\n'", 'belowstyle': "' background: #ddd;\n'", 'labelstyle': "' background: inherit;\n\n'", 'header1': "' Observation data ' + if(trim(if(epoch<includeonly>|</includeonly> != null, epoch<includeonly>|</includeonly>, '')) != '', '(' + if(epoch != null, epoch, '') + ' ' + 'epoch' + ') ', '') + '\n'", 'label2': "' Pronunciation\n'", 'data2': "' ' + if(pronounce<includeonly>|</includeonly> != null, pronounce<includeonly>|</includeonly>, '') + '\n\n'", 'label3': "' ' + 'Constellation' + '\n'", 'data3': "' ' + if(constellation_name<includeonly>|</includeonly> != null, constellation_name<includeonly>|</includeonly>, '') + '\n'", 'label4': "' ' + 'Right ascension' + '\n'", 'data4': "' ' + if(ra<includeonly>|</includeonly> != null, ra<includeonly>|</includeonly>, '') + '\n'", 'label5': "' ' + 'Declination' + '\n'", 'data5': "' ' + if(dec<includeonly>|</includeonly> != null, dec<includeonly>|</includeonly>, '') + '\n\n'", 'label6': "' ' + 'Redshift' + '\n'", 'data6': "' ' + if(z<includeonly>|</includeonly> != null, z<includeonly>|</includeonly>, '') + '\n'", 'label7': "' ' + 'Helio radial velocity' + '\n'", 'data7': "' ' + if(h_radial_v<includeonly>|</includeonly> != null, h_radial_v<includeonly>|</includeonly>, '') + '\n'", 'label8': "' Galactocentric velocity\n'", 'data8': "' ' + if(gal_v<includeonly>|</includeonly> != null, gal_v<includeonly>|</includeonly>, '') + '\n'", 'label9': "' ' + 'Distance (comoving)' + '\n'", 'data9': "' ' + if(dist_pc<includeonly>|</includeonly> != null, dist_pc<includeonly>|</includeonly>, '') + '\n'", 'label10': "' ' + 'Distance' + '\n'", 'data10': "' ' + if(dist_ly<includeonly>|</includeonly> != null, dist_ly<includeonly>|</includeonly>, '') + '\n'", 'label11': "' ' + 'Group' + ' or ' + 'cluster' + '\n'", 'data11': "' ' + if(group_cluster<includeonly>|</includeonly> != null, group_cluster<includeonly>|</includeonly>, '') + '\n'", 'label12': "' ' + 'Apparent magnitude' + '&nbsp;' + '(V)' + '\n'", 'data12': "' ' + if(appmag_v<includeonly>|</includeonly> != null, appmag_v<includeonly>|</includeonly>, '') + '\n'", 'label13': "' ' + 'Apparent magnitude' + '&nbsp;' + '(B)' + '\n'", 'data13': "' ' + if(appmag_b<includeonly>|</includeonly> != null, appmag_b<includeonly>|</includeonly>, '') + '\n'", 'label14': "' ' + 'Absolute magnitude' + '&nbsp;' + '(V)' + '\n'", 'data14': "' ' + if(absmag_v<includeonly>|</includeonly> != null, absmag_v<includeonly>|</includeonly>, '') + '\n'", 'label15': "' ' + 'Absolute magnitude' + '&nbsp;' + '(B)' + '\n'", 'data15': "' ' + if(absmag_b<includeonly>|</includeonly> != null, absmag_b<includeonly>|</includeonly>, '') + '\n'", 'label16': "' ' + 'Surface brightness' + '&nbsp;' + '(specify)' + '\n'", 'data16': "' ' + if(sbrightness_specify<includeonly>|</includeonly> != null, sbrightness_specify<includeonly>|</includeonly>, '') + '\n\n'", 'header20': "' ' + if(trim(if(type<includeonly>|</includeonly> != null, type<includeonly>|</includeonly>, '') + if(mass<includeonly>|</includeonly> != null, mass<includeonly>|</includeonly>, '') + if(mass_light_ratio<includeonly>|</includeonly> != null, mass_light_ratio<includeonly>|</includeonly>, '') + if(size<includeonly>|</includeonly> != null, size<includeonly>|</includeonly>, '') + if(stars<includeonly>|</includeonly> != null, stars<includeonly>|</includeonly>, '') + if(size_v<includeonly>|</includeonly> != null, size_v<includeonly>|</includeonly>, '') + if(half_light_radius_pc<includeonly>|</includeonly> != null, half_light_radius_pc<includeonly>|</includeonly>, '') + if(half_light_radius_arcminsec<includeonly>|</in ...
# ERROR: label labelstyle does not have an associated data.
# ==========================
# Adaptive Cards template:
# {"type": "AdaptiveCard", "$schema": "http://adaptivecards.io/schemas/adaptive-card.json", "version": "1.5", "body": [{"type": "Container", "style": "emphasis", "$data": "${' ' + if(name<includeonly>|{{PAGENAME}}</includeonly> != null, name<includeonly>|{{PAGENAME}}</includeonly>, '') + '\n'}", "$when": "${length(trim($data)) > 0}", "items": [{"type": "TextBlock", "text": "${$data}", "style": "heading", "wrap": "true", "horizontalAlignment": "Center"}]}, {"type": "Image", "horizontalAlignment": "Center", "$data": "${' ' + if(image<includeonly>|</includeonly> != null, image<includeonly>|</includeonly>, '') + '\n'}", "url": "${$data}", "$when": "${length(trim($data)) > 0}"}, {"type": "TextBlock", "$data": "${' ' + if(caption<includeonly>|</includeonly> != null, caption<includeonly>|</includeonly>, '') + '\n'}", "text": "${$data}", "horizontalAlignment": "Center", "$when": "${length(trim($data)) > 0}", "wrap": "true"}, {"type": "Container", "style": "emphasis", "wrap": "true", "$data": "${' Observation data ' + if(trim(if(epoch<includeonly>|</includeonly> != null, epoch<includeonly>|</includeonly>, '')) != '', '(' + if(epoch != null, epoch, '') + ' ' + 'epoch' + ') ', '') + '\n'}", "$when": "${length(trim($data)) > 0}", "items": [{"type": "TextBlock", "text": "${$data}", "weight": "Bolder", "horizontalAlignment": "Center"}]}, {"type": "FactSet", "facts": [{"title": "${$data.title}", "$data": "${{'data': ' ' + if(pronounce<includeonly>|</includeonly> != null, pronounce<includeonly>|</includeonly>, '') + '\n\n', 'title': ' Pronunciation\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(constellation_name<includeonly>|</includeonly> != null, constellation_name<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Constellation' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(ra<includeonly>|</includeonly> != null, ra<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Right ascension' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(dec<includeonly>|</includeonly> != null, dec<includeonly>|</includeonly>, '') + '\n\n', 'title': ' ' + 'Declination' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(z<includeonly>|</includeonly> != null, z<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Redshift' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(h_radial_v<includeonly>|</includeonly> != null, h_radial_v<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Helio radial velocity' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(gal_v<includeonly>|</includeonly> != null, gal_v<includeonly>|</includeonly>, '') + '\n', 'title': ' Galactocentric velocity\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(dist_pc<includeonly>|</includeonly> != null, dist_pc<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Distance (comoving)' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(dist_ly<includeonly>|</includeonly> != null, dist_ly<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Distance' + '\n'}}", "value": "${$data.data}", "$when": "${length(trim($data.data)) > 0}"}, {"title": "${$data.title}", "$data": "${{'data': ' ' + if(group_cluster<includeonly>|</includeonly> != null, group_cluster<includeonly>|</includeonly>, '') + '\n', 'title': ' ' + 'Group' + ' or ' + 'cluster' + '\n'}}", "value": "${$data.data}",  ...
# Adaptive Cards data:
# {"name": "Milky Way", "epoch": "J2000", "constellation_name": "Sagittarius", "image": "300px", "type": "Sb, Sbc, or SB(rs)bc  (barred spiral galaxy)", "size": "Stellar disk: 185 \u00b1 15 kly  \nDark matter halo: 1.9 \u00b1"}
# ==========================
